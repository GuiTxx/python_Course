# %% [markdown]
# <a href="https://colab.research.google.com/github/GuiTxx/python_Course/blob/main/aula_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
texto = '2'
texto1 = str(2)
numero = 3
numero1 = int(3)
numero2 = float(3)
print(texto)
print(texto1)
print(numero)
print(numero1)
print(numero2)
# Out:
# 2
# 2
# 3
# 3
# 3.0

# %%
nome = input('Digite seu nome: ')
print("seu nome é: ",nome)
# Out:
# Digite seu nome: Guilherme
# seu nome é:  Guilherme
